# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to minimize
def f(x):
    return x**2  

# Derivative  
def df(x):
    return 2*x
  

# Gradient descent
learning_rate = 0.1  
x = 5 # Initial value

# Track values for plotting  
x_history = [x]

for i in range(10):
    x -= learning_rate * df(x)  
    # Track values
    x_history.append(x)
    print(f"Iteration {i+1}: x = {x}")

print(f"Final x is {x}")

# Plot optimization path
plt.plot(x_history)
plt.xlabel("Iteration") 
plt.ylabel("x value")
plt.title("Gradient Descent Optimization Path")

plt.show()
# Out:
# Iteration 1: x = 4.0
# Iteration 2: x = 3.2
# Iteration 3: x = 2.56
# Iteration 4: x = 2.048
# Iteration 5: x = 1.6384
# Iteration 6: x = 1.31072
# Iteration 7: x = 1.0485760000000002
# Iteration 8: x = 0.8388608000000002
# Iteration 9: x = 0.6710886400000001
# Iteration 10: x = 0.5368709120000001
# Final x is 0.5368709120000001

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to minimize
def f(x):
    return x**2  

# Derivative  
def df(x):
    return 2*x
  

# Gradient descent
learning_rate = 0.25  
x = 5 # Initial value

# Track values for plotting  
x_history = [x]

for i in range(10):
    x -= learning_rate * df(x)  
    # Track values
    x_history.append(x)
    print(f"Iteration {i+1}: x = {x}")

print(f"Final x is {x}")

# Plot optimization path
plt.plot(x_history)
plt.xlabel("Iteration") 
plt.ylabel("x value")
plt.title("Gradient Descent Optimization Path")

plt.show()
# Out:
# Iteration 1: x = 2.5
# Iteration 2: x = 1.25
# Iteration 3: x = 0.625
# Iteration 4: x = 0.3125
# Iteration 5: x = 0.15625
# Iteration 6: x = 0.078125
# Iteration 7: x = 0.0390625
# Iteration 8: x = 0.01953125
# Iteration 9: x = 0.009765625
# Iteration 10: x = 0.0048828125
# Final x is 0.0048828125

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to minimize
def f(x):
    return x**2  

# Derivative  
def df(x):
    return 2*x
  

# Gradient descent
learning_rate = 0.2  
x = 5 # Initial value

# Track values for plotting  
x_history = [x]

for i in range(10):
    x -= learning_rate * df(x)  
    # Track values
    x_history.append(x)
    print(f"Iteration {i+2}: x = {x}")

print(f"Final x is {x}")

# Plot optimization path
plt.plot(x_history)
plt.xlabel("Iteration") 
plt.ylabel("x value")
plt.title("Gradient Descent Optimization Path")

plt.show()
# Out:
# Iteration 2: x = 3.0
# Iteration 3: x = 1.7999999999999998
# Iteration 4: x = 1.0799999999999998
# Iteration 5: x = 0.6479999999999999
# Iteration 6: x = 0.3887999999999999
# Iteration 7: x = 0.23327999999999993
# Iteration 8: x = 0.13996799999999995
# Iteration 9: x = 0.08398079999999997
# Iteration 10: x = 0.05038847999999998
# Iteration 11: x = 0.030233087999999984
# Final x is 0.030233087999999984
